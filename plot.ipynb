# %% [markdown]
# <a href="https://colab.research.google.com/github/subhash-ranjan/matplotlib-pg/blob/main/plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import Libraries

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# Basic graphs

# %%
x=[1,2,3]
y = [4,5,6]

plt.plot(x,y,'b*--')

x1 = np.arange(0,4, .5)
plt.plot(x1, x1**2, 'r--', label='x^2')
plt.show()

# %% [markdown]
# Gas price data example

# %%
gas_price_data = pd.read_csv('gas_prices.csv')

plt.figure(figsize=(10,6))

# plt.plot(gas_price_data.Year, gas_price_data.USA,'b.-', label='USA')
# plt.plot(gas_price_data.Year, gas_price_data.Canada, label='Canada')
# plt.plot(gas_price_data.Year, gas_price_data['South Korea'], label='South Korea')

for item in gas_price_data:
  if item != 'Year' and item != 'Australia':
    plt.plot(gas_price_data.Year, gas_price_data[item], marker='.', label=item)

plt.legend()
plt.show()

# %% [markdown]
# ## Load Fifa data

# %%
fifa = pd.read_csv('fifa_data.csv')

# %% [markdown]
# Histograms

# %%
bins = [40,50,60,70,80,90,100]
plt.hist(fifa.Acceleration)

plt.xticks(bins)
plt.xlabel('Skill Level')
plt.ylabel('No of Players')
plt.title('Distributions of skills')

plt.show()

# %% [markdown]
# Pie Charts

# %%
left_foot = fifa.loc[fifa['Preferred Foot']=='Left'].count()[0]
right_foot = fifa.loc[fifa['Preferred Foot']=='Right'].count()[0]

plt.pie([left_foot,right_foot], labels=['Left Foot', 'RIght Foot'],autopct='%.2f')
plt.title('Foot preference of FIFA players')
plt.show()

# %% [markdown]
# Weight distributions of FIFA players

# %%
fifa.Weight = [int(x.strip('lbs')) if type(x)==str else x  for x in fifa.Weight]

light = fifa.loc[fifa.Weight<125].count()[0]
light_medium = fifa.loc[(fifa.Weight>125) & (fifa.Weight<150)].count()[0]
medium = fifa.loc[(fifa.Weight>150) & (fifa.Weight<175)].count()[0]
medium_heavy = fifa.loc[(fifa.Weight>175) & (fifa.Weight<200)].count()[0]
heavy = fifa.loc[fifa.Weight>200].count()[0]

weights = [light,light_medium,medium,medium_heavy,  heavy]
labels = ['<125','125-150','150-175','175-200','>200', ]
plt.pie(weights, labels=labels, autopct='%.2f', pctdistance=0.8, explode=(.4,.1,0,0,.4))
plt.style.use('ggplot')
plt.show()
